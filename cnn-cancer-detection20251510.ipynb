# %%
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        os.path.join(dirname, filename)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2
from glob import glob
from PIL import Image
import random
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Activation, MaxPooling2D, Dropout, Flatten, Dense, Multiply, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau
# Out:
# 2025-05-12 02:22:43.686384: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747016563.927367      31 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747016563.993910      31 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# Define directories
directory  = '../input/histopathologic-cancer-detection'  
labels_path = os.path.join(directory, 'train_labels.csv')
train_path = os.path.join(directory, 'train')
test_path = os.path.join(directory, 'test')

# %%
print('There are ',len(os.listdir(train_path)), 'training images and ',len(os.listdir(test_path)), 'testing images.')
# Out:
# There are  220025 training images and  57458 testing images.

# %%
# load the CSV file containing labels
labels = pd.read_csv(labels_path)

# create a DataFrame to match training data images with labels
train = pd.DataFrame({'path': glob(os.path.join(train_path, '*.tif'))}) 
train['id'] = train['path'].map(lambda x: os.path.splitext(os.path.basename(x))[0])  # Extract image ID to merge with training labels
train = train.merge(labels, on='id')  

# convert labels to strings
train['label'] = train['label'].astype(str)

# ensure paths are relative to train_path
train['path'] = train['path'].apply(lambda x: os.path.basename(x))

print(train.head())
# Out:
#                                            path  \
# 0  d43c081bafa286f9c1f7e921883f26ceafebc912.tif
# 1  092d0eedebce504847715ee046b6ad74b57599b4.tif
# 2  b0d2582c6218a8764323fc940b41312282b99bf4.tif
# 3  187c99df762f13f99818e5593d4bab4c6577e7e3.tif
# 4  7c5270c83837de5a5cbb2dca511559dc39d19d53.tif
#
#                                          id label
# 0  d43c081bafa286f9c1f7e921883f26ceafebc912     1
# 1  092d0eedebce504847715ee046b6ad74b57599b4     0
# 2  b0d2582c6218a8764323fc940b41312282b99bf4     0
# 3  187c99df762f13f99818e5593d4bab4c6577e7e3     1
# 4  7c5270c83837de5a5cbb2dca511559dc39d19d53     1

# %% [markdown]
# ## Data Exploration

# %%
# check for null values
print('There are ',train.isnull().sum().sum(), ' null values')
# check for duplicates
print('There are ', train.duplicated().sum(),' duplicated images')
# Out:
# There are  0  null values
# There are  0  duplicated images

# %%
# randomly select one image path
image_path = random.choice(train['path'].values)
# full path to the image
full_image_path = os.path.join(train_path, image_path)
# Load the selected image 
selected_image = cv2.imread(full_image_path)

print('Image shape is ', selected_image.shape)
print('The maximum number of pixels is ', selected_image.max())
# Out:
# Image shape is  (96, 96, 3)
# The maximum number of pixels is  255

# %%
# Separate cancerous and non-cancerous data
cancerous = train[train['label'] == '1']['id'].sample(n=5).values  # Treat labels as strings
noncancerous = train[train['label'] == '0']['id'].sample(n=5).values

cancerous_images = []
for id in cancerous:
    image_path = os.path.join(train_path, id + '.tif')
    cancerous_images.append(Image.open(image_path))

noncancerous_images = []
for id in noncancerous:
    image_path = os.path.join(train_path, id + '.tif')
    noncancerous_images.append(Image.open(image_path))

plt.figure(figsize=(10, 5))
for i, image in enumerate(cancerous_images):
    plt.subplot(1, 5, i+1)
    plt.imshow(image)
    plt.title('Cancerous')
    plt.axis('off')
plt.show()

plt.figure(figsize=(10, 5))
for i, image in enumerate(noncancerous_images):
    plt.subplot(1, 5, i+1)
    plt.imshow(image)
    plt.title('Non-Cancerous')
    plt.axis('off')
plt.show()

# %%
# Counts for each class
label_counts = labels['label'].value_counts()

# Calculate the percentages of each class
positive_percentage = label_counts[1] / (label_counts[0] + label_counts[1])
print(f'Positive labels in training data: {positive_percentage:.2%}')

# Bar plot 
plt.figure(figsize=(7, 5))
ax = label_counts.sort_index().plot(kind='bar', color=['blue', 'red'])

plt.xticks([0, 1], labels=[f"Cancer Negative N={label_counts[0]}", f"Cancer Positive N={label_counts[1]}"], rotation=0)

for i, count in enumerate(label_counts):
    percentage = count / label_counts.sum() * 100
    ax.text(i, count + 500, f'{percentage:.2f}%', ha='center', va='bottom', fontsize=12)

plt.title(f'Distribution of Training Data')
plt.ylabel('Count')
plt.xlabel(" ")
plt.tight_layout()

# Save plot to kaggle output directory
#plt.savefig('/kaggle/working/training_data_distribution.png', dpi=300)

plt.show()
# Out:
# Positive labels in training data: 40.50%

# %% [markdown]
# ## Data Generators with Gaussian Smoothing
# Gaussian smoothing removes noise while preserving edges.

# %%
def gaussian_smooth(image):
    # Convert image to unit8
    image = (image * 255).astype(np.uint8)

    #Convert image to RGB
    if image.shape[-1] == 1:
        image = cv2.cvtColor(image, cv2.COLOR_GRAY2BGR)

    # Gaussian smoothing (blur)
    image = cv2.GaussianBlur(image, (3, 3), 0)

    # Convert float 32 and range of [0,1]
    return image.astype(np.float32) / 255.0

# %%
# Split the data into 80% training and 20% validation sets
train_df, val_df = train_test_split(train, test_size=0.2, random_state=42)

# Data generator for training images
train_datagen = ImageDataGenerator(
    rescale=1./255,  # scale images from 0-255 to 0-1
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True, 
    #preprocessing_function=gaussian_smooth
)

# Data generator for validation images without augmentation
validation_datagen = ImageDataGenerator(
    rescale=1./255,  # scale images from 0-255 to 0-1
    #preprocessing_function=gaussian_smooth
)

batch_size = 32

# Generator for the training set
train_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    directory=train_path,
    x_col='path',
    y_col='label',
    target_size=(96, 96), # image shape
    batch_size=batch_size,
    class_mode='binary',
    shuffle=True
)

# Generator for the validation set
validation_generator = validation_datagen.flow_from_dataframe(
    dataframe=val_df,  
    directory=train_path,
    x_col='path',
    y_col='label',
    target_size=(96, 96),
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False
)
# Out:
# Found 176020 validated image filenames belonging to 2 classes.
# Found 44005 validated image filenames belonging to 2 classes.

# %% [markdown]
# ## Model with Spacial Attention
# Spatial attention mechanisms help the network to selectively focus on specific regions within an image while suppressing less relevant areas. This model will also use a learning rate scheduler to decrease the learning rate during training if it detects the model isn’t improving enough.

# %%
def spatial_attention_block(input_tensor, kernel_size=7):
    # Generates attention features through a separate pathway
    attention = Conv2D(filters=1, kernel_size=kernel_size, padding='same', activation='sigmoid')(input_tensor)
    #attention = BatchNormalization()(attention)

    # Apply attention to input
    refined_features = Multiply()([input_tensor, attention])

    return refined_features

# %%
reduce_lr = ReduceLROnPlateau(
    monitor = 'val_loss',
    factor = 0.5, # 50% Reduction in learning Rate
    patience = 2, # If no improvement after 2 epochs
    verbose = 1,
    min_lr = 1e-6 # minimum learning rate not to go below
)

# %%
# Define input
inputs = Input(shape=(96, 96, 3))

x = Conv2D(64, (3, 3), padding='same', activation='relu', kernel_regularizer=l2(0.001))(inputs)
# Spatial attention layer
# Using kernel_size=9 then kernel_size=3 to capture both global and local spatial dependencies
x = spatial_attention_block(x, kernel_size=9)
x = spatial_attention_block(x, kernel_size=3)
x = Dropout(0.05)(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

x = Conv2D(128, (3, 3), padding='same', activation='relu', kernel_regularizer=l2(0.001))(x)
x = Dropout(0.1)(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

x = Conv2D(256, (3, 3), padding='same', activation='relu', kernel_regularizer=l2(0.001))(x)
x = Dropout(0.15)(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

x = Conv2D(512, (3, 3), padding='same', activation='relu', kernel_regularizer=l2(0.001))(x)
# 2nd spatial attention layer, allows the model to re-focus after deep feature extraction
x = spatial_attention_block(x, kernel_size=9)
x = spatial_attention_block(x, kernel_size=3)
x = Dropout(0.2)(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

# Global Average Pooling to reduce spatial dimensions
x = GlobalAveragePooling2D()(x)

# Fully connected layers
x = Dense(256)(x)
x = Dropout(0.3)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

# Output layer
outputs = Dense(1, activation='sigmoid', kernel_regularizer=l2(0.001))(x)

# Build model
model_spatial = Model(inputs, outputs)

# %%
model_spatial.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1             │ (None, 96, 96, 3)      │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_8 (Conv2D)         │ (None, 96, 96, 64)     │          1,792 │ input_layer_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_9 (Conv2D)         │ (None, 96, 96, 1)      │          5,185 │ conv2d_8[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_4 (Multiply)     │ (None, 96, 96, 64)     │              0 │ conv2d_8[0][0],        │
# │                           │                        │                │ conv2d_9[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_10 (Conv2D)        │ (None, 96, 96, 1)      │            577 │ multiply_4[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_5 (Multiply)     │ (None, 96, 96, 64)     │              0 │ multiply_4[0][0],      │
# │                           │                        │                │ conv2d_10[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_5 (Dropout)       │ (None, 96, 96, 64)     │              0 │ multiply_5[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_5     │ (None, 96, 96, 64)     │            256 │ dropout_5[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_4           │ (None, 48, 48, 64)     │              0 │ batch_normalization_5… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_11 (Conv2D)        │ (None, 48, 48, 128)    │         73,856 │ max_pooling2d_4[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_6 (Dropout)       │ (None, 48, 48, 128)    │              0 │ conv2d_11[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_6     │ (None, 48, 48, 128)    │            512 │ dropout_6[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_5           │ (None, 24, 24, 128)    │              0 │ batch_normalization_6… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_12 (Conv2D)        │ (None, 24, 24, 256)    │        295,168 │ max_pooling2d_5[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_7 (Dropout)       │ (None, 24, 24, 256)    │              0 │ conv2d_12[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_7     │ (None, 24, 24, 256)    │          1,024 │ dropout_7[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_6           │ (None, 12, 12, 256)    │              0 │ batch_normalization_7… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_13 (Conv2D)        │ (None, 12, 12, 512)    │      1,180,160 │ max_pooling2d_6[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_14 (Conv2D)        │ (None, 12, 12, 1)      │         41,473 │ conv2d_13[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_6 (Multiply)     │ (None, 12, 12, 512)    │              0 │ conv2d_13[0][0],       │
# │                           │                        │                │ conv2d_14[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_15 (Conv2D)        │ (None, 12, 12, 1)      │          4,609 │ multiply_6[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_7 (Multiply)     │ (None, 12, 12, 512)    │              0 │ multiply_6[0][0],      │
# │                           │                        │                │ conv2d_15[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_8 (Dropout)       │ (None, 12, 12, 512)    │              0 │ multiply_7[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_8     │ (None, 12, 12, 512)    │          2,048 │ dropout_8[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_7           │ (None, 6, 6, 512)      │              0 │ batch_normalization_8… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 512)            │              0 │ max_pooling2d_7[0][0]  │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_2 (Dense)           │ (None, 256)            │        131,328 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_9 (Dropout)       │ (None, 256)            │              0 │ dense_2[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_9     │ (None, 256)            │          1,024 │ dropout_9[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_1 (Activation) │ (None, 256)            │              0 │ batch_normalization_9… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_3 (Dense)           │ (None, 1)              │            257 │ activation_1[0][0]     │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 1,739,269 (6.63 MB)
#  Trainable params: 1,736,837 (6.63 MB)
#  Non-trainable params: 2,432 (9.50 KB)

# %%
model_spatial.compile(
    optimizer=Adam(learning_rate=0.0001),
    loss='binary_crossentropy',
    metrics=['accuracy', 'auc']
)

# %% [markdown]
# Keras was prematurely ending training and moving to the next epoch, most likely because Keras didn't have enough data to complete all the steps per epoch. Therefor Keras was allowed to automatically determine the number of steps_per_epoch and Validation_stpes.

# %%
#steps_per_epoch = len(train_df)//batch_size
#validation_steps = len(val_df)//batch_size

hist_spatial = model_spatial.fit(
    train_generator,
    #steps_per_epoch = steps_per_epoch, 
    validation_data = validation_generator,
    #validation_steps = validation_steps,
    epochs = 20,
    callbacks=[reduce_lr]
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1746987809.314885      79 service.cc:148] XLA service 0x7b7538002810 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1746987809.322189      79 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1746987809.322230      79 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1746987810.318910      79 cuda_dnn.cc:529] Loaded cuDNN version 90300
#    2/5501 ━━━━━━━━━━━━━━━━━━━━ 8:39 94ms/step - accuracy: 0.4219 - auc: 0.4239 - loss: 1.4458
# I0000 00:00:1746987823.694060      79 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 5501/5501 ━━━━━━━━━━━━━━━━━━━━ 2096s 377ms/step - accuracy: 0.8359 - auc: 0.9060 - loss: 0.8093 - val_accuracy: 0.8825 - val_auc: 0.9452 - val_loss: 0.4445 - learning_rate: 1.0000e-04
# Epoch 2/20
# 5501/5501 ━━━━━━━━━━━━━━━━━━━━ 937s 170ms/step - accuracy: 0.8991 - auc: 0.9581 - loss: 0.3742 - val_accuracy: 0.8847 - val_auc: 0.9626 - val_loss: 0.3621 - learning_rate: 1.0000e-04
# Epoch 3/20
# 5501/5501 ━━━━━━━━━━━━━━━━━━━━ 920s 167ms/step - accuracy: 0.9148 - auc: 0.9679 - loss: 0.3074 - val_accuracy: 0.8959 - val_auc: 0.9644 - val_loss: 0.3386 - learning_rate: 1.0000e-04
# Epoch 4/20
# 5501/5501 ━━━━━━━━━━━━━━━━━━━━ 952s 173ms/step - accuracy: 0.9223 - auc: 0.9725 - loss: 0.2812 - val_accuracy: 0.8682 - val_auc: 0.9702 - val_loss: 0.3853 - learning_rate: 1.0000e-04
# Epoch 5/20
# 5501/5501 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9281 - auc: 0.9757 - loss: 0.2640
# Epoch 5: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 5501/5501 ━━━━━━━━━━━━━━━━━━━━ 932s 169ms/step - accuracy: 0.9281 - auc: 0.9757 - loss: 0.2640 - val_accuracy: 0.8486 - val_auc: 0.9460 - val_loss: 0.4501 - learning_rate: 1.0000e-04
# Epoch 6/20
# 5501/5501 ━━━━━━━━━━━━━━━━━━━━ 950s 173ms/step - accuracy: 0.9395 - auc: 0.9819 - loss: 0.2313 - val_accuracy: 0.8572 - val_auc: 0.9542 - val_loss: 0.4531 - learning_rate: 5.0000e-05
# Epoch 7/20
# 5501/5501 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9427 - auc: 0.9840 - loss: 0.2154
# Epoch 7: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 5501/5501 ━━━━━━━━━━━━━━━━━━━━ 923s 168ms/step - accuracy: 0.9427 - auc: 0.9840 - loss: 0.2154 - val_accuracy: 0.8826 - val_auc: 0.9498 - val_loss: 0.3407 - learning_rate: 5.0000e-05
# Epoch 8/20
# 5501/5501 ━━━━━━━━━━━━━━━━━━━━ 914s 166ms/step - accuracy: 0.9504 - auc: 0.9868 - loss: 0.1964 - val_accuracy: 0.8932 - val_auc: 0.9688 - val_loss: 0.3187 - learning_rate: 2.5000e-05
# Epoch 9/20
# 5501/5501 ━━━━━━━━━━━━━━━━━━━━ 937s 170ms/step - accuracy: 0.9532 - auc: 0.9882 - loss: 0.1842 - val_accuracy: 0.9356 - val_auc: 0.9868 - val_loss: 0.2175 - learning_rate: 2.5000e-05
# Epoch 10/20
# 5501/5501 ━━━━━━━━━━━━━━━━━━━━ 926s 168ms/step - accuracy: 0.9543 - auc: 0.9889 - loss: 0.1795 - val_accuracy: 0.9285 - val_auc: 0.9865 - val_loss: 0.2316 - learning_rate: 2.5000e-05
# Epoch 11/20
# 5501/5501 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9558 - auc: 0.9894 - loss: 0.1745
# Epoch 11: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 5501/5501 ━━━━━━━━━━━━━━━━━━━━ 914s 166ms/step - accuracy: 0.9558 - auc: 0.9894 - loss: 0.1745 - val_accuracy: 0.9021 - val_auc: 0.9758 - val_loss: 0.3010 - learning_rate: 2.5000e-05
# Epoch 12/20
# 5501/5501 ━━━━━━━━━━━━━━━━━━━━ 961s 174ms/step - accuracy: 0.9590 - auc: 0.9908 - loss: 0.1655 - val_accuracy: 0.9038 - val_auc: 0.9791 - val_loss: 0.2945 - learning_rate: 1.2500e-05
# Epoch 13/20
# 5501/5501 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.9619 - auc: 0.9918 - loss: 0.1571
# Epoch 13: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 5501/5501 ━━━━━━━━━━━━━━━━━━━━ 975s 177ms/step - accuracy: 0.9619 - auc: 0.9918 - loss: 0.1571 - val_accuracy: 0.9239 - val_auc: 0.9874 - val_loss: 0.2364 - learning_rate: 1.2500e-05
# Epoch 14/20
# 5501/5501 ━━━━━━━━━━━━━━━━━━━━ 1029s 187ms/step - accuracy: 0.9631 - auc: 0.9922 - loss: 0.1531 - val_accuracy: 0.9434 - val_auc: 0.9886 - val_loss: 0.1957 - learning_rate: 6.2500e-06
# Epoch 15/20
# 5501/5501 ━━━━━━━━━━━━━━━━━━━━ 1003s 182ms/step - accuracy: 0.9650 - auc: 0.9927 - loss: 0.1484 - val_accuracy: 0.9345 - val_auc: 0.9878 - val_loss: 0.2157 - learning_rate: 6.2500e-06
# Epoch 16/20
# 5501/5501 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.9646 - auc: 0.9926 - loss: 0.1480
# Epoch 16: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 5501/5501 ━━━━━━━━━━━━━━━━━━━━ 989s 180ms/step - accuracy: 0.9646 - auc: 0.9926 - loss: 0.1480 - val_accuracy: 0.9382 - val_auc: 0.9838 - val_loss: 0.2091 - learning_rate: 6.2500e-06
# Epoch 17/20
# 5501/5501 ━━━━━━━━━━━━━━━━━━━━ 978s 178ms/step - accuracy: 0.9668 - auc: 0.9934 - loss: 0.1419 - val_accuracy: 0.9414 - val_auc: 0.9865 - val_loss: 0.2007 - learning_rate: 3.1250e-06
# Epoch 18/20
# 5501/5501 ━━━━━━━━━━━━━━━━━━━━ 988s 179ms/step - accuracy: 0.9671 - auc: 0.9935 - loss: 0.1414 - val_accuracy: 0.9444 - val_auc: 0.9878 - val_loss: 0.1941 - learning_rate: 3.1250e-06
# Epoch 19/20
# 1669/5501 ━━━━━━━━━━━━━━━━━━━━ 9:54 155ms/step - accuracy: 0.9693 - auc: 0.9944 - loss: 0.1347

# %%
plt.figure(figsize=(10, 5))

# accuracy plot
plt.subplot(1, 3, 1)
plt.plot(hist_spatial.history['accuracy'], label='Train Accuracy')
plt.plot(hist_spatial.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim(0.700, 1.000)
plt.title('Model Accuracy')
plt.legend(loc='lower right')

# loss plot
plt.subplot(1, 3, 2)
plt.plot(hist_spatial.history['loss'], label='Train Loss')
plt.plot(hist_spatial.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Model Loss')
plt.legend(loc='upper right')

# AUC plot
plt.subplot(1, 3, 3)
plt.plot(hist_spatial.history['auc'], label='Train AUC')
plt.plot(hist_spatial.history['val_auc'], label='Validation AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.title('ROC AUC')
plt.legend(loc='lower right')

plt.tight_layout()
# Save plot to kaggle output directory (optional)
plt.savefig('/kaggle/working/cnn_training_results.png', dpi=300)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_31/1672448981.py in <cell line: 0>()
#       3 # accuracy plot
#       4 plt.subplot(1, 3, 1)
# ----> 5 plt.plot(hist_spatial.history['accuracy'], label='Train Accuracy')
#       6 plt.plot(hist_spatial.history['val_accuracy'], label='Validation Accuracy')
#       7 plt.xlabel('Epoch')
#
# NameError: name 'hist_spatial' is not defined

# %% [markdown]
# ## Confusion Matrix

# %%
# calculations for confusion matrix
true_labels = validation_generator.classes
pred_probabilities = model_spatial.predict(validation_generator, steps=len(validation_generator), verbose=1)

# for binary classification get predicted classes based on probability threshold of 0.5
pred_classes = (pred_probabilities > 0.5).astype(int)

# confusion matrix
cm = confusion_matrix(true_labels, pred_classes)

# plot confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Non-Cancerous', 'Cancerous'])
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix')

# Save plot to kaggle output directory (optional)
plt.savefig('/kaggle/working/cnn_training_confusion.png', dpi=300)
plt.show()
